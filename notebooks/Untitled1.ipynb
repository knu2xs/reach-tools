# %%
import requests

# %%
url = "https://trpc-api.americanwhitewater.org/reach/reachDetailWithPhotos?batch=1&input=%7B%220%22%3A%7B%22json%22%3A%7B%22reachID%22%3A%222169%22%7D%7D%7D"

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# [{'result': {'data': {'json': {'id': '2169',
#      'stub': {'id': '2169',
#       'section': '2 - Mashel River to Mckenna',
#       'altname': '',
#       'river': 'Nisqually',
#       'difficulty': 'II',
#       'states': ['USA-WSH']},
#      'primaryGaugeStatus': {'status': 'below-recommended',
#       'latestReading': {'value': '979',
#        'dateTime': '2026-05-12T01:00:00.000Z',
#        'qualifier': 'NORMAL'},
#       'metric': 'cfs',
#       'adjustedDifficulty': None},
#      'pointOfInterests': [{'type': 'put-in',
#        'description': 'If you can access the site in Pack Forest, it is possible to launch boats on the Mashel River just upstream of the Nisqually River confluence. You can also hike in or transport a boat with a cart.',
#        'id': '112086',
#        'location': {'latitude': '46.846994', 'longitude': '-122.331089'},
#        'name': 'Mashel River Confluence Put In',
#        'distance': '0.01',
#        'photoID': '886036',
#        'difficulty': 'N/A',
# ...
